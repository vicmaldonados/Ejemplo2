# %% [markdown]
# ## Ejercicio
#
# Escribir un programa que pida al usuario una palabra y la muestre 10 veces por pantalla.

# %% [markdown]
# ## Solución

# %%
word = input("Introduce una palabra: ")
for i in range(10):
    print(word)
# Out:
# Introduce una palabra: Victor
# Victor
# Victor
# Victor
# Victor
# Victor
# Victor
# Victor
# Victor
# Victor
# Victor
